# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import numpy as np
import os
import pickle

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# /var/folders/lb/1lkw03z108jdt_8x1dlcpgnc0000gn/T/ipykernel_67846/912229180.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %%
# fld_data_path = '/home/vshejwalkar_umass_edu/fedrecover/FLDetector_plots_data'
fld_data_path = '/Users/momin/Downloads/fedrecover/FLDetector_plots_data'


mnist_slow_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_slow_mean.pkl'), 'rb'))
mnist_slow_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_slow_median.pkl'), 'rb'))
mnist_slow_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_slow_trmean_trim20.pkl'), 'rb'))
mnist_slow_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_slow_median_trim20.pkl'), 'rb'))

mnist_fast_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_fast_mean.pkl'), 'rb'))
mnist_fast_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_fast_median.pkl'), 'rb'))
mnist_fast_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_fast_trmean_trim20.pkl'), 'rb'))
mnist_fast_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_mnist_fast_median_trim20.pkl'), 'rb'))


fashion_slow_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_slow_mean.pkl'), 'rb'))
fashion_slow_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_slow_median.pkl'), 'rb'))
fashion_slow_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_slow_trmean_trim20.pkl'), 'rb'))
fashion_slow_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_slow_median_trim20.pkl'), 'rb'))

fashion_fast_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_fast_mean.pkl'), 'rb'))
fashion_fast_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_fast_median.pkl'), 'rb'))
fashion_fast_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_fast_trmean_trim20.pkl'), 'rb'))
fashion_fast_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_fashion_fast_median_trim20.pkl'), 'rb'))



femnist_slow_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_slow_mean.pkl'), 'rb'))
femnist_slow_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_slow_median.pkl'), 'rb'))
femnist_slow_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_slow_trmean_trim20.pkl'), 'rb'))
femnist_slow_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_slow_median_trim20.pkl'), 'rb'))

femnist_fast_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_fast_mean.pkl'), 'rb'))
femnist_fast_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_fast_median.pkl'), 'rb'))
femnist_fast_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_fast_trmean_trim20.pkl'), 'rb'))
femnist_fast_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_femnist_fast_median_trim20.pkl'), 'rb'))



cifar_slow_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_slow_mean_resnet20BN.pkl'), 'rb'))
cifar_slow_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_slow_median_resnet20BN_glr.2.pkl'), 'rb'))
cifar_slow_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_slow_trmean_trim20_resnet20BN.pkl'), 'rb'))
cifar_slow_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_slow_median_trim20_resnet20BN_glr.2.pkl'), 'rb'))

cifar_fast_trmean = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_fast_mean_resnet20BN.pkl'), 'rb'))
cifar_fast_median = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_fast_median_resnet20BN.pkl'), 'rb'))
cifar_fast_trmean_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_fast_trmean_trim20_resnet20BN.pkl'), 'rb'))
cifar_fast_median_trim20 = pickle.load(open(os.path.join(fld_data_path, 'rq1_baseline_cifar10_fast_median_trim20_resnet20BN.pkl'), 'rb'))

# %%
mnist_slow_trmean.keys()
# Out:
# odict_keys(['final_accs_per_client', 'accs_per_round', 'best_accs_per_round'])

# %%
# fig, axs = plt.subplots(1,1, figsize=(15,3))
fig, axs = plt.subplots()
plt.figure(figsize=(8,5))

# MNIST
slow_x = np.arange(len(mnist_slow_trmean['accs_per_round']))
slow_x_ = np.arange(0, len(slow_x), 10)
fast_x = np.arange(len(mnist_fast_trmean['accs_per_round']))
# axs[0].set_title('MNIST')
axs.plot(slow_x_, 100*mnist_slow_trmean['accs_per_round'][slow_x_], linestyle='dashed', linewidth=2, color='teal', label='FedSGD no-attack')
axs.plot(slow_x_, 100*mnist_slow_trmean_trim20['accs_per_round'][slow_x_], linestyle='dashed', linewidth=2, color='tomato', label='FedSGD attack')
axs.plot(fast_x, mnist_fast_trmean['accs_per_round'], linestyle='solid', linewidth=2, color='teal', label='FedAVG no-attack')
axs.plot(fast_x, mnist_fast_trmean_trim20['accs_per_round'], linestyle='solid', linewidth=2, color='tomato', label='FedAVG attack')

# axs[0].plot(slow_x_, 100*mnist_slow_median['accs_per_round'][slow_x_], marker='.', linestyle='solid', color='dodgerblue', label='Slow Median w/o attack')
# axs[0].plot(slow_x_, 100*mnist_slow_median_trim20['accs_per_round'][slow_x_], marker='.', linestyle='dashed', color='orange', label='Slow Median w/ attack')
# axs[0].plot(fast_x, mnist_fast_median['accs_per_round'], linestyle='solid', color='dodgerblue', label='Fast Median w/o attack')
# axs[0].plot(fast_x, mnist_fast_median_trim20['accs_per_round'], linestyle='dashed', color='orange', label='Fast Median w/ attack')

# axs[0].set_xticks(classes)
axs.legend(fontsize=18)
axs.tick_params(axis='x', labelsize = 20)
axs.tick_params(axis='y', labelsize = 20)
axs.set_ylim(0,100)
axs.set_xlabel("Round", fontsize=24)
axs.set_ylabel("Accuracy (%)", fontsize=24)
axs.grid()

# # Fashion
# slow_x_fashion = np.arange(len(fashion_slow_trmean['accs_per_round']))
# slow_x_fashion_ = np.arange(0, len(slow_x_fashion), 10)
# fast_x_fashion = np.arange(len(fashion_fast_trmean['accs_per_round']))
# # axs[1].set_title('Fashion-MNIST')
# axs.plot(slow_x_fashion_, 100*fashion_slow_trmean['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth=2, color='teal', label='FedSGD no-attack')
# axs.plot(slow_x_fashion_, 100*fashion_slow_trmean_trim20['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth=2, color='tomato', label='FedSGD attack')
# axs.plot(fast_x_fashion, fashion_fast_trmean['accs_per_round'], linestyle='solid', linewidth=2, color='teal', label='FedAVG no-attack')
# axs.plot(fast_x_fashion, fashion_fast_trmean_trim20['accs_per_round'], linestyle='solid', linewidth=2, color='tomato', label='FedAVG attack')

# # axs[1].plot(slow_x_fashion_, 100*fashion_slow_median['accs_per_round'][slow_x_fashion_], marker='.', linestyle='solid', color='dodgerblue', label='Slow Median w/o attack')
# # axs[1].plot(slow_x_fashion_, 100*fashion_slow_median_trim20['accs_per_round'][slow_x_fashion_], marker='.', linestyle='dashed', color='orange', label='Slow Median w/ attack')
# # axs[1].plot(fast_x, fashion_fast_median['accs_per_round'], linestyle='solid', color='dodgerblue', label='Fast Median w/o attack')
# # axs[1].plot(fast_x, fashion_fast_median_trim20['accs_per_round'], linestyle='dashed', color='orange', label='Fast Median w/ attack')
# axs.tick_params(axis='x', labelsize = 20)
# axs.tick_params(axis='y', labelsize = 20)
# axs.set_ylim(0,100)
# axs.set_xlabel("Round", fontsize = 24)
# axs.grid()


# # FEMNIST
# slow_x_femnist = np.arange(len(femnist_slow_trmean['accs_per_round']))
# slow_x_femnist_ = np.arange(0, len(slow_x_femnist), 10)
# fast_x_femnist = np.arange(len(femnist_fast_trmean['accs_per_round']))
# # axs[2].set_title('FEMNIST')
# axs.plot(slow_x_femnist_, femnist_slow_trmean['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth = 2, color='teal', label='FedSGD no-attack')
# axs.plot(slow_x_femnist_, femnist_slow_trmean_trim20['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth = 2, color='tomato', label='FedSGD attack')
# axs.plot(fast_x_femnist, femnist_fast_trmean['accs_per_round'], linestyle='solid', linewidth = 2, color='teal', label='FedAVG no-attack')
# axs.plot(fast_x_femnist, femnist_fast_trmean_trim20['accs_per_round'], linestyle='solid', linewidth = 2, color='tomato', label='FedAVG attack')
# axs.tick_params(axis='x', labelsize = 20)
# axs.tick_params(axis='y', labelsize = 20)
# axs.set_ylim(0,100)
# axs.set_xlabel("Round", fontsize = 24)
# axs.grid()

# # CIFAR10
# slow_x_cifar = np.arange(len(cifar_slow_trmean['accs_per_round'][1:]))
# slow_x_cifar_ = np.arange(0, len(slow_x_cifar), 10)
# fast_x_cifar = np.arange(len(cifar_fast_trmean['accs_per_round']))
# # axs[3].set_title('CIFAR10')
# axs.plot(slow_x_cifar_, 100*cifar_slow_trmean['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth = 2, color='teal', label='FedSGD no-attack')
# axs.plot(slow_x_cifar_, 100*cifar_slow_trmean_trim20['accs_per_round'][slow_x_fashion_], linestyle='dashed', linewidth = 2, color='tomato', label='FedSGD attack')
# axs.plot(fast_x_cifar, 100*cifar_fast_trmean['accs_per_round'], linestyle='solid', linewidth = 2, color='teal', label='FedAVG no-attack')
# axs.plot(fast_x_cifar, 100*cifar_fast_trmean_trim20['accs_per_round'], linestyle='solid', linewidth = 2, color='tomato', label='FedAVG attack')
# axs.tick_params(axis='x', labelsize = 20)
# axs.tick_params(axis='y', labelsize = 20)
# axs.set_ylim(0,100)
# axs.set_xlabel("Round", fontsize = 24)
# axs.grid()


plt.show()
plt.tight_layout()
fig.savefig('baseline_mnist.pdf', bbox_inches = 'tight')
# fig.savefig(os.path.join(fld_data_path, 'figs/fld_rq1_baselines.pdf'))
